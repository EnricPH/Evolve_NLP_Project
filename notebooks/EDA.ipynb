# %% [markdown]
# # **EDA Analysis — electricalworld.com | Electronics & Technology**

# %% [markdown]
# ### **Libraries**

# %%
import re
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.patches as mpatches
import seaborn as sns

import unicodedata
import logging
from typing import Optional

from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# Own libraries
import sys
if '../src' not in sys.path:
    sys.path.append('../src')
import cleaning
import eda

# %% [markdown]
# ### **Sector & Company Configuration**

# %%
TARGET = "electricalworld.com"
CAT = "Electronics & Technology"

# %% [markdown]
# ### **Data Load**
#
# #### **Companies Dataset**
# - This dataset is going to be loaded just to visualize which portion of the total each `category` represents.
# - In this dataset all companies have the maximum of a **100** reviews.
# - The values of the columns: `median_stars`, `media_stars`, `std_stars`, are the same for all countries, so no additional information is given.

# %%
company_category = pd.read_excel("../datasets/emp_100_reviews.xlsx")
company_category.head()
# Out:
#              category                 company  n_reviews  median_stars  \
# 0      Animals & Pets        gardenbird.co.uk        100             3
# 1  Restaurants & Bars  www.brewersfayre.co.uk        100             3
# 2  Restaurants & Bars         mindfulchef.com        100             3
# 3  Restaurants & Bars        nonnatonda.co.uk        100             3
# 4  Restaurants & Bars         planthood.co.uk        100             3
#
#    media_stars  std_stars
# 0            3   1.421338
# 1            3   1.421338
# 2            3   1.421338
# 3            3   1.421338
# 4            3   1.421338

# %%
# Get the normalized value counts
category_props = company_category['category'].value_counts(normalize=True)

# Create horizontal barplot
plt.figure(figsize=(12, 6))

# Create horizontal bars
category_props.plot(kind='barh')

# Add titles and labels
plt.title('Distribution of Company Categories', fontsize=16, fontweight='bold')
plt.xlabel('Proportion (Percentage)', fontsize=12)
plt.ylabel('Company Category', fontsize=12)

# Add percentage labels on bars
for i, (category, value) in enumerate(category_props.items()):
    plt.text(value + 0.005, i, f'{value:.1%}', 
             va='center', fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# For this project we are going to work with a company of the `Electronics & Technology` category. However the procedure followed is going to be exactly the same for all categories.
#
# Now let's see the companies of this category that have a **100 reviews**

# %%
company_category.loc[company_category['category']==CAT, 'company'].unique()
# Out:
# <ArrowStringArray>
# [                 'backmarket.co.uk',             'hotpointservice.co.uk',
#                      'belling.co.uk',                         'bopdj.com',
#                'directvacuums.co.uk',               'electricalworld.com',
#                       'giffgaff.com',                   'go-assist.co.uk',
#                        'gtech.co.uk',                      'hughes.co.uk',
#                    'www.tayna.co.uk',                'www.mrmemory.co.uk',
#               'www.partmaster.co.uk',              'www.petertyson.co.uk',
#               'www.richersounds.com', 'www.sevenoakssoundandvision.co.uk',
#              'www.sonicdirect.co.uk',                     'www.vax.co.uk',
#                  'mobiletopup.co.uk',         'www.markselectrical.co.uk',
#                 'www.lcegroup.co.uk',                   'www.jessops.com',
#                 'www.idmobile.co.uk',                  'www.hivehome.com',
#                    'www.ghdhair.com',                 'www.espares.co.uk',
#                     'www.ebuyer.com',                   'www.dyson.co.uk',
#                   'www.currys.co.uk',               'www.buyspares.co.uk',
#         'www.appliancesdirect.co.uk',           'www.appliancecity.co.uk',
#                           'uw.co.uk',                       'subcold.com',
#                   'sharkclean.co.uk',                'ransomspares.co.uk']
# Length: 36, dtype: str

# %% [markdown]
# #### **Reviews Dataset**

# %%
df = pd.read_csv("../datasets/trustpilot-reviews-123k.csv")
df.head()
#df[df['category']==CAT].head()
# Out:
#          category                    company  \
# 0  Animals & Pets  ruffandtumbledogcoats.com
# 1  Animals & Pets  ruffandtumbledogcoats.com
# 2  Animals & Pets  ruffandtumbledogcoats.com
# 3  Animals & Pets  ruffandtumbledogcoats.com
# 4  Animals & Pets  ruffandtumbledogcoats.com
#
#                                          description  \
# 0  At Ruff and Tumble we are proud to be the mark...
# 1  At Ruff and Tumble we are proud to be the mark...
# 2  At Ruff and Tumble we are proud to be the mark...
# 3  At Ruff and Tumble we are proud to be the mark...
# 4  At Ruff and Tumble we are proud to be the mark...
#
#                                      title  \
# 0  Great quality dog drying robe although…
# 1                    Really prompt service
# 2                               Life saver
# 3                          Brilliant coats
# 4               Great company and products
#
#                                               review  stars
# 0  Great quality dog drying robe although had to ...      5
# 1  Really prompt service, The sofa covers have no...      5
# 2  I’ve purchased first of those coats in May2020...      5
# 3  Brilliant coats. Really like the limited editi...      5
# 4  Great company and products. This is my 3rd dry...      5

# %% [markdown]
# Quick ``title`` and ``review`` column check

# %%
# Display each review one by one
for idx, row in df.loc[df['company']=='electricalworld.com', ['title', 'review']].iterrows():
    print(f"\n{'='*50}")
    print(f"Title: {row['title']}")
    print(f"Review: {row['review']}")
    print(f"{'='*50}")
# Out:
# ==================================================
# Title: Christmas Lights Success
# Review: Tried everywhere to get a specific set of Christmas Lights to match the other six sets we had around the windows.  Thankfully Electrical World had them in stock and at a much better price than any of the other stockists we had looked at.  Prompt delivery, item well packaged and exactly what we were after!  Thank you!
# ==================================================
#
# ==================================================
# Title: Product was as expected and great value…
# Review: Product was as expected and great value for money. Nice silky soft furry cover. I ordered 6 in total 4 with covers and 2 without covers. Given to various family members who were pleased and grateful as just in time as weather had turned a lot colder. Packaged well. I can honestly and easily recommend.
# ==================================================
#
# ==================================================
# Title: Great Company and Service
# Review: Great Web site, easy to order, good communication , quick delivery and very fair prices. Will use this company again. Product well wrapped snd as described.
# ==================================================
#
# ==================================================
# Title: I had great experience shopping with…
# Review: I had great experience shopping with Electrical world there service is very fast and easy to order on website
# ==================================================
#
# ==================================================
# Title: Great experience!
# Review: Great experience, fast delivery, can’t fault anything. Will definitely be ordering again in the future.
# ==================================================
#
# ==================================================
# Title: Excellent value
# Review: Easy to use website, quick delivery, excellent price, kept well informed of delivery.
# ==================================================
#
# ==================================================
# Title: Best priced
# Review: Best priced, fast delivery, what more could you ask for. Delivery driver actually rang the door bell, better than those who just leave parcels anywhere and then leave.
# ==================================================
#
# ==================================================
# Title: Fast Delivery, great heat
# Review: Very impressed with delivery to Ireland, had product within two days when website said between 3-5 days.Bought the portable heater and Works very well and great heat. Cheaper to buy on this website than some stores in Ireland also.
# ==================================================
#
# ==================================================
# Title: Very quick delivery happy with the…
# Review: Very quick delivery happy with the product would buy again
# ==================================================
#
# ==================================================
# Title: Great quality products at great prices…
# Review: 2nd time to order from here. Great quality products at great prices with fast delivery, website is easy to use and was kept updated about order progress from start to finish
# ==================================================
#
# ==================================================
# Title: Highly recommended
# Review: Ordered several items, the ones that were in stock arrived in 2 days, the rest needed to be ordered in - got update emails every step of the way. Very happy with the purchase and customer service. Will definitely order again.
# ==================================================
#
# ==================================================
# Title: Excellent service. 2nd order I've made…
# Review: This is the 2nd order I've made for dog treats. The company is very quick delivering and the products have passed the dog taste test 😋. Our labrador loves them. A very good selection on the website too. Would definitely recommend this company
# ==================================================
#
# ==================================================
# Title: Product quality & Customer experience
# Review: I purchased a Neon battery light for some Christmas decor. I am very please with the products quality. Electircal worlds website is accessible and smooth to engage with and the delivery was fast. Highly recommended
# ==================================================
#
# ==================================================
# Title: Easy to navigate the website and place…
# Review: Easy to navigate the website and place an order. Everything arrived quickly and in perfect condition. Thank you Electrical World.
# ==================================================
#
# ==================================================
# Title: I had searched everywhere for some…
# Review: I had searched everywhere for some batteries. Manage to find them here at Electrical World. I found ordering process easy. I was kept uptodate re the order dispatch and the batteries arrived in a timely manner. no complaints will use these again for sure.
# ==================================================
#
# ==================================================
# Title: Perfect
# Review: Good delivery time and I wasn't expecting my package on that day and they even left it in with my neighbors so it's a yes from me and will I shop there again definitely
# ==================================================
#
# ==================================================
# Title: A fantastic company to deal with
# Review: A fantastic company to deal with. Ordered an extension cord for a generator and it arrived within 3 days. Quick and easy.
# ==================================================
#
# ==================================================
# Title: Items I ordered recently were delivered…
# Review: Items I ordered recently were delivered very quickly. Pricing was excellent. Very happy with product, thankyou
# ==================================================
#
# ==================================================
# Title: Excellent communicationquick delivery which as a customer…
# Review: Very quick delivery which as a customer is paramount. Packaging of my Irish Turf was in sealed sacks so were easily stacked Extremely helpful and very well priced.Excellent company which I will purchase from again and again. Thank you
# ==================================================
#
# ==================================================
# Title: I couldn't believe the price of…
# Review: I couldn't believe the price of Electrical Worlds coloured filament fairy lights....just a fraction of everywhere else on the internet. Initially I bought 3 sets, not believing they would actually be delivered but the arrived within a few days so I ordered 5 sets more. Delighted with my purchase.
# ==================================================
#
# ==================================================
# Title: Decent
# Review: I give it 4 because I haven't use the hose yet so that's the only reason I won't give 5 is I don't wanna jynx it but other than that very quick with delivery and no problems, value for money...! 👌
# ==================================================
#
# ==================================================
# Title: Trustworthy company!
# Review: Although the item was damaged(through transit I would imagine)a refund was swiftly given. good communication and would recommend this company.
# ==================================================
#
# ==================================================
# Title: Great and affordable prices
# Review: Great, affordable prices. Good communication when requesting an update on my order. Able to track parcel. Gave our stars as outer packaging as quite damaged. But order was intact. Will order again
# ==================================================
#
# ==================================================
# Title: I needed to replace the 12" fluorescent…
# Review: I needed to replace the 12" fluorescent tube in my larder. Looking for the replacement I found that this was a somewhat rare size for such a tube (actually 11.25"), but Electrical World had this tube AND correctly described it (an 8Watt 380Lumen T5 Halophosphate Tube), so NOT an LED tube which has become the standard in the more common sizes. However, no starter was supplied, so I am still using the old original starter, which appears to be defective since I need to insert AND release the starter each time I switch the light on. I would have expected a new starter to be supplied with a new tube especially if the tube is likely to be a different sort from the previous one. Please tell me if I appear to be unreasonable in having this expectation!
# ==================================================
#
# ==================================================
# Title: The shipment arrived at the agreed…
# Review: The shipment arrived at the agreed time. Good quality item, as described. I was concerned about tracking the shipment, there was no  of status updates, the outdated name of the courier company scared me, Hermes has not existed for a long time, there is Evri now. And in fact, a nice older gentleman from Evri delivered the item on time 😊
# ==================================================
#
# ==================================================
# Title: Straightforward purchase
# Review: Straightforward purchase. Item well packed and arrived within three working days. Would use again.Only reason for 4 stars and not 5 was simply that the 'track package' link in the order acknowledgement did not work and the online help was a little frustrating to use.
# ==================================================
#
# ==================================================
# Title: Had what I wanted
# Review: Had what I wanted. Swift delivery. Customer service seem on the ball. Lost a star due to incomplete order being received, customer service have promised to rectify.
# ==================================================
#
# ==================================================
# Title: Every thing delivered as ordered in a…
# Review: Every thing delivered as ordered in a timely manner. Competitive prices too.DPD the courier left a box of 6 lamps in front of my front door unhidden in the pouring rain all day.  When I got back from work the rain saturated the outer box and some of the inside boxes were wet too.What happens if £160 worth of lamps get taken from the doorstep??
# ==================================================
#
# ==================================================
# Title: The item arrived in good condition
# Review: The item arrived in good condition, however the delivery wasn't acceptable; it was a last minute delivery at around 7.30 pm in the evening even though it was apparently on the van from early morning; an AM or PM slot would be useful and convenient.
# ==================================================
#
# ==================================================
# Title: I needed a Draper 12m forcing screw…
# Review: I needed a Draper 12m forcing screw Electric World had a couple in stock. Ordered one fast reasonable shipping my set was up to par two weeks later.      Thanks Electrical World.   Jay H
# ==================================================
#
# ==================================================
# Title: Portable heated towel rail and shopping experience
# Review: Customer support responded to my queries. Quick delivery. Portable heated towel rail is very lightweight. A bit fiddly to attach the feet but steady once secure. Low wattage.
# ==================================================
#
# ==================================================
# Title: Clear Cut pricing and fast delivery
# Review: Clear Cut pricing and fast delivery. Accurate descriptions . Easy to find what we need
# ==================================================
#
# ==================================================
# Title: The item was broken when it arrived and they’ve not got back to me.
# Review: The item was broken when it arrived. It was not packaged appropriately. Ive not had a response from electrical world I’ve sent 2 emails to customer services I I will give a little more time before I contact my card provider.Electrical world has since contacted me and have furnished me with the replacement parts for the pruner. I’m Happy with the way it has now been dealt with.
# ==================================================
#
# ==================================================
# Title: Good price, seems like a decent product
# Review: The fluorescent tubes were a good price compared to other retailers, dispatched quickly and came very well protected with packing. They fit perfectly and work as expected, only time will tell how long they last
# ==================================================
#
# ==================================================
# Title: Good experience
# Review: Website is easy to navigate and ordering was simple too. The only reason for four stars was that delivery took longer than I originally anticipated but maybe that's a lesson to me to double check such things!
# ==================================================
#
# ==================================================
# Title: Great selection of items
# Review: Great selection of items. Clear descriptions.Website did say items available for quick dispatch although this clearly didn’t happen.
# ==================================================
#
# ==================================================
# Title: Easy ordering online
# Review: Easy ordering online. Great description of the product with measurements which is great as you are sure you are buying the correct product. Quick dispatch and delivery. Will use again for sure.Thank you.
# ==================================================
#
# ==================================================
# Title: Good experience except for the courier delivery
# Review: The company itself was great everything was really smooth from the initial order and customer service responses I could not fault it . I would definitely use them again but suggest they add a box to their delivery section to enable delivery directions The only reason I did not give 5 stars is that they use DPD as delivery couriers and as we live in on a  new estate DPD kept saying they tried to deliver but we were not in which was completely untrue and trying to get through to DPD to actually speak to someone was an absolute nightmare . It took a lot of effort and frustration before DPD actually delivered our item although it was in good condition and working order
# ==================================================
#
# ==================================================
# Title: Order processed seamlessly and great…
# Review: Order processed seamlessly and great price on product,unfortunately FedEx let their side down by delivering 2 days later than they should
# ==================================================
#
# ==================================================
# Title: I ordered a toaster from EW in…
# Review: I ordered a toaster from EW in December, it blew up this week which was really annoying and surprising, but I am told toasters do that sometimes.I emailed them to let them know, sent them proof of the fault, and they refunded me straight away. Thank you!
# ==================================================
#
# ==================================================
# Title: After sales left bad taste in mouth
# Review: Ordering, payment and despatch straightforward enough. I received a faulty item though - one of the trugs arrived without its handle. In itself not a problem as these things happen. I reported it and requested a replacement. Simple enough? Not at all! I had to upload photos of the item (really, what do you think a trug without a handle looks like?), of the packaging (surely only relevant if damage in transit is the problem?), of the postage label. This then unleashed a whole series of e-mails offering various degrees of reduction on the price rather than a replacement. Each time I reiterated my original request to send a replacement - a trug without no handle is pretty useless after all. Unfortunately it’s left a bad taste in my mouth - I’ve been put to an awful lot of effort to achieve a resolution to a straightforward problem that occurred their end. Still not received the replacement but hope it’s on its way.
# ==================================================
#
# ==================================================
# Title: Item arrived quickly at a good price
# Review: Item arrived quickly at a good price, however full dimensions of product not described on website.
# ==================================================
#
# ==================================================
# Title: The buckets I ordered are great and…
# Review: The buckets I ordered are great and just what I need for my current project. No quibbles with them at all. Unfortunately the delivery let it down. As with this shipment, everything I have ever had to wait for to be delivered by evri/hermes has been long-winded, with no proper tracking info or communication.
# ==================================================
#
# ==================================================
# Title: Disappointing
# Review: Good: Good priceSimple to order Goods arrived as described (after checking)Bad:Within a few hours of me ordering there was a big discount of 30% on the same product for black Friday which they would not apply but there was no notice they were going to be doing BF deals or I would have waited.The photo on the website did not match the colour description so I had to check which was correct.It took six days for delivery.The link for tracking never worked and Evri delivery said they had had to tape up the box as it was too flimsy   The order was 444574. I already replied.You've even sent me another link to review saying I hadn't reviewed my order. Er, what is this then?   28th November - you said you would resolve this, I replied as requested. Heard no more....
# ==================================================
#
# ==================================================
# Title: Really good prices on some garden tools…
# Review: Really good prices on some garden tools I bought. Delivery info was vague and innaccurate. I'm still waiting for the last delivery which was shown as despatched 2 weeks ago but hasn't left yet.  So, good if you have no deadlines.  Update: after chasing up the order, which was a little painful, the last shipment was dispatched and arrived. 22 days after ordering. So, everything received in good condition, presumably something went wrong at some point, either in communication or the dispatch
# ==================================================
#
# ==================================================
# Title: I've returned to provide an update
# Review: I've returned to provide an update. Eventually got half my order. It's an absolutely beautiful lantern, but omg the stress of the experience.Other half the order is out of stock and I'm still waiting for my refund!They have some nice things at a good price (when they are available!). Sort out your customer service technology and your stock control and you might just stop all these 1 star reviews.
# ==================================================
#
# ==================================================
# Title: Communication!
# Review: Ordered 4 planters but received only 2. Only on contacting company did I learn that they were awaiting stock. How hard would it have been to inform me in advance that the order would be incomplete on receipt.Had that happened I would have been fully satisfied with the service.
# ==================================================
#
# ==================================================
# Title: Product never delivered
# Review: UPDATE: After chasing up by email I have now received the refund, hence updated ranking of the review. I ordered paint from them on 8th August and as of 13th September I don’t have either the paint or the date of delivery. After multiple emails giving me updated date of delivery which never materialises, I think I’ll have no option but to go through chargeback as I doubt that the refund will be dealt with. The delivery was supposed to happen within 3-5 working days so it is now over a month late.
# ==================================================
#
# ==================================================
# Title: Would give less than one star if could…
# Review: Would give less than one star if could ordered items in March which never arrived, after agreeing the time scale was not acceptable by the company there is still no return of money they took to my bank account despite numerous e-mails and promises to get it sorted over €100 taken and not an item to show for it 😡 Since writing this review the money has been returned to my accountThank you Electrical world you have now put things right
# ==================================================
#
# ==================================================
# Title: Delivery service
# Review: Not impressed with courier delivery company.Would prefer royal mail postal service.My order Order (#433053) was delivered by EVRI (Hermes) courier.The problem I had was several hours before my delivery, I received a very realistic SCAM message on my mobile phone stating they were EVRI & they needed confirmation of my address plus a small additional charge for postage.As I knew my package wes been sent from N.I. I initially thought this was authentic.I therefore checked with friends and neighbours who told me it is a regular scam pretending to be EVRI courier. Therefore I think the Royal mail postal service is a better option than a courier.
# ==================================================
#
# ==================================================
# Title: Watch out you don't have to return anything!
# Review: I ordered x4 T4 slimline flourescent tubes. Unfortunately, I ordered the wrong length & they turned out to be 10mm too short!I requested a return following Electrical World's instructions given on their website. This was easy to do & Electrical World provide a pre-paid delivery label via Royal Mail service. I had to wait two weeks after Electrical World received the return before I received a refund. To my horror, Electrical World had deducted a fortune for the cost of the return, which equated to half the cost of the order. If I had have known that they do this, I would have used Royal Mail's 24hr Tracked & Signed for service for a cheaper price!Not a pleased customer, who will be shopping elsewhere..
# ==================================================
#
# ==================================================
# Title: Delivery disappointing
# Review: I paid £6.95 on a Tuesday for delivery of some mouse traps in 1 to 2 working days . They had still not been despatched  by Saturday . Mouse very happy 😊 I contacted Electrical World on Saturday and although I didn’t get a reply for a couple of days , the traps were sent on Saturday  morning and delivered on Sunday . Mouse now getting used to outdoor living . Excellent ! The delay was disappointing however having paid the extra postage
# ==================================================
#
# ==================================================
# Title: Please with the products,however
# Review: Please with the products,however, I still haven't received all of my order. No notification to say I wouldn't be getting all of my order. Still waiting! so a little disappointed. The products themselves are lovely and really pleased.
# ==================================================
#
# ==================================================
# Title: Eterna brand and not Crompton
# Review: Delivery took a little longer than expected, possibly due to Christmas period and fact that package seemed to go through Belfast. Arrived safely.  Only comment is that items are not Crompton brand as advertised; but Eterna.  Fine if they do the job - but obviously too early to say.
# ==================================================
#
# ==================================================
# Title: Bird feeder sent quickly but not great quality
# Review: Bird feeder was dispatched quickly, but the clips to hold the bottom part of the feeder in place are very thin plastic which don't spring back fully. I can see the bottom part falling off before long (which would mean all the sunflower hearts falling out). I couldn't be bothered to return it though.
# ==================================================
#
# ==================================================
# Title: Ordered a log store and wrong product…
# Review: Ordered a log store and wrong product was sent, the log store was also missing a wooden slat. Customer Service took a while to respond and finally issued 25% refund as replacement wasn't in stock. OK product but wouldn't purchase garden items from again.
# ==================================================
#
# ==================================================
# Title: Ghosted by Customer Services
# Review: Ordered items from website for delivery, costing nearly £100. When arrived they were not what I had ordered. Contacted "Customer Services" to be told firstly that they didn't believe me and then when picture proof was sent that they would arrange collection. After waiting a few days and no contact they then started offering me a small partial refund if I would keep the items. I kept stating that I would like what I had ordered or my money back and the other items collected. This has been going on for over 4 weeks now and still no response to rectify their mistake. BE AWARE EXTREMELY POOR CUSTOMER SERVICE AND SELLING ITEMS THEY DON'T ACTUALLY HAVE ON THEIR WEBSITE!!!!!UPDATE 12/10/23Finally sorted the issue and offered a full refund without collecting items. Took too long to rectify but got there in the end only after leaving a poor review on here.
# ==================================================
#
# ==================================================
# Title: Item purchased turned up to be "not in stock"
# Review: Like so many recent one-star reviews, I placed an order (bread maker for a price of £61) on December 18th. The order was acknowledged but I received an email on December 22nd informing me the item was not "yet" available. I have emailed the company three times and even spent on the phone almost one hour two days ago, all to no avail. So far, the above was my initial feedback. I have to say that very early in the New Year I was not only contacted but refunded what I had paid for an item that was not in stock. Hence I am modifying the stars given to the company. The only thing I would add is that as a customer you need to check that the item you are buying is in stock and the company needs to let the customers know when their customer service is limited (for example during the Christmas period).
# ==================================================
#
# ==================================================
# Title: Uncertainty
# Review: I didn't like not being able to contact Electrical World . . . . I wasn't available for delivery on Saturday and would have liked to change it, but I couldn't and I didn't know that it would be delivered.
# ==================================================
#
# ==================================================
# Title: Product is good
# Review: Product is good. The website order doesn’t specify at what price the delivery charges be added. Needed to buy another item and had to pay delivery charges extra. Previous buy no charges. Could help!
# ==================================================
#
# ==================================================
# Title: This is my second review for the same…
# Review: This is my second review for the same product that I ordered and paid for on 30 October 2024. It is now 3 January 2025 and I have still not received it. I have however been given 3 dates for delivery, all of which have passed.My first request for a refund was ignored, so I am attempting again to get my money back.I have given 2 stars, as at least they have communicated with me, albeit with false information.
# ==================================================
#
# ==================================================
# Title: Disappointing.
# Review: Nothing wrong with the product, just let down by delivery times and the customer service experience. 9 days to receive the order. It's beyond frustrating being given automated emails as updates and having to wait 24-48 hours for a response, in fact I've just received another courtesy email 2 weeks later saying my order is still being worked on, even though It's already been delivered.
# ==================================================
#
# ==================================================
# Title: Damaged on arrival
# Review: Two of the 10 light bulbs were shattered on arrival - 20% of my order. I don’t know if this happened before they were shipped or during transit, but the delivery was not marked to be handled with care.
# ==================================================
#
# ==================================================
# Title: Delays to dispatch, website information incorrect
# Review: Ordered two items, one in stock for next day dispatch, one estimated a few days later. Website delivery info states items with status of 'in stock for fast delivery' will be dispatched next day if ordered after 2pm, and that in order to get items out as quick as possible, orders will be split if needed. No dispatch info received, tried calling but auto phone line directs you to live chat to request a call back. Live chat doesn't have a request to call option, or free text option, and says cannot link my orders. Sent a message request through website. Did have a helpful member of staff then explain that my order size meant it wasn't eligible to be split, but that based on the lack of clarity on the website, she would split and dispatch. Hoping for order to arrive today, but it's been very frustrating, and have had to place a second order and pay for express delivery to ensure it arrived, which it hasn't.
# ==================================================
#
# ==================================================
# Title: So wish I had looked at these reviews…
# Review: So wish I had looked at these reviews before dealing with fhis company! Placed an order for my dog food, paid for delivery 2/3 day duration. 6 days later I'm still waiting. No access to tracking, no contact number to speak with someone. The only contact being a ridiculous bot chat or email which is rarely if ever responded to.My order has finally arrived today, a week after ordering it, no thanks to the virtually non existence of a functioning customer service.Sorry Electrical World, but I wont be purchasing from you again nor will I be recommending you. Just not worth the hassle and aggravation. Order 437078
# ==================================================
#
# ==================================================
# Title: Product never arrived and had to chase refumd
# Review: Product advertised on website but not actually available in stock. Order stuck in progress for months despite being repeatedly told it would be shipped next week. Refund process took way too long also with multiple follow ups to support before being processed. Cannot recommend and unlikely to use again.
# ==================================================
#
# ==================================================
# Title: Ordered replacement light bulbs as…
# Review: Ordered replacement light bulbs as stated despatch was in 2-3 days.  They took the money.  A few days later received an email indicating they did not have stock.  Tried emailing, using live chat and phoning - no response from customer service on any channel.  Still nothing delivered after 10 days.Finally got through by phone after many unsuccessful attempts. Order despatched after 15 days.
# ==================================================
#
# ==================================================
# Title: Poor Customer service etiquette. Wrong colour tray arrived but luckily i didnt mind the colour.
# Review: I purchased a green boot tray from Electrical world.Firstly it was a few weeks late, I believe i had one automated email apologising for the delay. After a few weeks had passed and I wrote directly I received a response saying it 'should' arrive that week, i note there was no offer of an apology for the delay by the customer service representative.The tray did arrive that week, however, it arrived in an incorrect colour.As it so happens I'd ordered Green and it arrived black, which i was also happy with.But this did not fill me with much hope that I'd order from this company again.
# ==================================================
#
# ==================================================
# Title: I wish I had read the reviews before…
# Review: I wish I had read the reviews before placing my order. The shipping time was two weeks but six weeks later I am still waiting. The ‘customer service’ chat is pathetic and just goes around in circles. Doesn’t send the verification code or says it doesn’t recognise your email!I am just going to request a chargeback via my bank and I would strongly urge other customers to do the same. This scamming company needs shutting down. ORDER NUMBER FOR WHAT IT IS WORTH IS 424998I placed this order on the 20th of July. Thank you for your very flippant reply! Ridiculous customer service
# ==================================================
#
# ==================================================
# Title: Very disappointed
# Review: Very disappointed, I purchased an item and 10 minutes later I needed to cancel as I realised I didn’t need to purchase the full item , but just the small part I required. Sent an email and rang explaining this but was told the item was already dispatched, hard to believe !!!!! but as a result I won’t be buying from them anymore.
# ==================================================
#
# ==================================================
# Title: Ordered a lava lamp for my niece's…
# Review: Ordered a lava lamp for my niece's birthday - I then started receiving emails saying they were waiting for some part to be in stock so there was a delay. I kept receiving these emails so finally emailed them to which they stated they did not have that colour lava lamp in stock. Why is it on the website then? By this point it had been 3 weeks so I agreed for a different colour but very disappointed. Customer Service were quick at replying so that's why it isn't 1 star but won't be using again! Ridiculous.
# ==================================================
#
# ==================================================
# Title: Took the risk of ordering something…
# Review: Took the risk of ordering something that was supposed to be dispatched in 5-10 days, 13 days later received an email saying they are still working on it...If they've got something in stock might be worth ordering but there seems to be a pattern of if they say 5-10 days that deadline may well not be met.
# ==================================================
#
# ==================================================
# Title: Not the product ordered
# Review: Although the lamp that was delivered was a good product it was not the same as the one I ordered and I wanted the lamp that was on the website as I need a charger for the two I have, so a disappointing experience as I was not told that the product was not the same . Order number 435439
# ==================================================
#
# ==================================================
# Title: I ordered from Electrical world and…
# Review: I ordered from Electrical world and paid for express shipping assuming it would be only a few days wait.Turns out as confirmed by customer service there is a 15-30 days processing period.Paying for express shipping does not "over ride" this period. So the express shipping only applies after the 15-30 day period.So if your ordering don't bother with express shipping you will be waiting about a month anyway.
# ==================================================
#
# ==================================================
# Title: Misleading delivery times
# Review: It’s not clear on the website or order confirmation that you have to add together the dispatch and delivery times to figure out when your order will arrive…The website hides this information in small print which is not impressive.Dispatch for the items I ordered was 7-14 days while delivery was an additional 3-5 working days. In theory that’s a 3 week wait which is not standard for the delivery cost that you pay (£3.95 for standard).
# ==================================================
#
# ==================================================
# Title: Im disappointed
# Review: Im really disappointed as have ordered from this company previously and have never had any problems. This time I ordered some more rose compost as last time it was great but my parcel got delivered to the wrong area. Fed ex and electrical world were very helpful in tracking down the parcel and thanks to the fed ex man he found my parcel and re delivered it to the right address. When I opened up the compost to pot up my rose the compost was absolutely awful I have never seen anything like it before. It doesn’t even look like compost. So disappointing and nothing like the bags I have had in previous orders!! Makes me unsure whether to order from this company again which is a shame!
# ==================================================
#
# ==================================================
# Title: The plant pot I ordered arrived chipped…
# Review: The plant pot I ordered arrived chipped in a very unsuitable cardboard box, I informed the company it was chipped and they offered me a 10% refund as if they were doing me a favour.  When I told them I didn’t want a chipped plant pot they did arrange a return post paid.
# ==================================================
#
# ==================================================
# Title: Placed an order on the 29 March 2024…
# Review: Placed an order on the 29 March 2024 for two bags of dog food which I had to cancel as it had not arrived. Still waiting for my refund after contacting the company 3-4 times! Still no refund even though the company stated on their reply that I had been!!! Still no refund as promised and Klarna has now raised a dispute
# ==================================================
#
# ==================================================
# Title: Still waiting for my order.
# Review: Placed an order on March 14th. Have looked for updates to be told that they will have the item by the end of the week. Six weeks later, still being told the same thing even when I have looked for a refund. Unless they say that they currently have the item in stock, I would avoid using this company in future. Update: Item was eventually delivered 8 weeks from date of purchase after much back and forth via email. When I insisted upon a refund, this was ignored and I was told that it would be delivered that week.
# ==================================================
#
# ==================================================
# Title: Placed my order on Tue 22nd Nov 2023.
# Review: Placed my order on Tue 22nd Nov 2023.Told it was dispatched on Fri 24th.Royal mail message said delivery on Mon 27th. Nothing arrived. Next day Tue, Royal mail message said deliver that day, nothing arrived. Sent email to Electrical world, no reply, Now Friday Dec 1st, nothing arrived so….sent went in chat line to Electrical World, not live at time they post as being contactable, so left message. Phoned them shortly after, stayed on hold for just over 37 minutes and eventually gave up. So I am left with no parcel, no contact and when trying to contact Royal mail, just go round in a loop with no real contact.Where does one go from here ?? It would appear that this company is not set up for proper customer service.Would I use them again….?     Not a chance !Not sure who is worse…Royal Mail or Electrical World.
# ==================================================
#
# ==================================================
# Title: Purchased tulip spinners
# Review: Purchased tulip spinners, web page shows multiple colours, put in a request for one of each (must admit to putting the request in the delivery instructions) items turned up and they were all red!Sent an email to them and they said that they only have the red ones. If I had known this I would not have purchased them, as they were specifically for my autistic granddaughter. Not a happy customer.
# ==================================================
#
# ==================================================
# Title: Customer Service Managed By Mickey Mouse
# Review: Absolutely awful company with regard to their customer service. Ordered item, website states rapid delivery, nearly 4 days later and the order hasn't even been processed, tried cancelling, no email acknowledgement, tried live chat, but no response, tried calling automated message which tells you to try live chat. Will await refund or get a charge-back.  A total Mickey Mouse company.
# ==================================================
#
# ==================================================
# Title: Very poor service
# Review: Very poor service, I ordered an external light fitting at the beginning of December which has not arrived and I’ve not been updated throughout the process. I would avoid ordering from this company.
# ==================================================
#
# ==================================================
# Title: Seriously disappointed
# Review: Seriously disappointed! Bought and paid for items. When arrived, one item missing off the order I tried contacting Electrical World a number of times and they completely ignore my emails and requests made on their on-line contact.This company cannot be trusted.
# ==================================================
#
# ==================================================
# Title: I ordered a lead on the 10th December…
# Review: I ordered a lead on the 10th December with plenty of time to be delivered before Christmas.  I chased this up on the 18th and was told it was to be delivered that day. It didn't arrive so contacted them again on the 19th to be told its making its way to their dispatch warehouse.  Here we are on the 23rd of December and I've now been told there is a backlog but it's still making its way to the despatch wherehouse. Good customer service would of been contacting me say on the 11th or 12th telling me there was a delay and offering a refund.  But no just lie and delay and keep telling me you know how important it is that I get the item for Christmas. Avoid this company unless you like being lied to and can wait for your item with no idea if it will be dispatched.
# ==================================================
#
# ==================================================
# Title: Fobbed off!
# Review: 447565 (order no) Purchased dog food on 28 Nov and was showing as in stock. Payment left my account but still not received the food. Contacted customer services by the ridiculous chat feature several times and keep being stalled. Apparently they received it into warehouse on Tuesday but still no tracking info!!! Very poor customer service.Edited to add - I've just been offered a refund despite being told 3 days ago it was in the warehouse and being expedited to me. Avoid this company at all costs! Now how long will.the refund take? I'll update you!
# ==================================================
#
# ==================================================
# Title: Ordered 2 lights one worked one didn't
# Review: Ordered 2 lights one worked one didn't. I was asked to send pictures of the box which was in 100% good condition. To date l not received any correspondence from this company. After sales very poor.  Please bear this in mind when ordering from Electrical World
# ==================================================
#
# ==================================================
# Title: Goods order 18th Nov 24
# Review: Goods order 18th Nov 24 Website states UK DELIVERY 7 DAYS .ABSOLUTE NONSENSE..........24 DAYS LATERmy goods arrived.I've contacted the company on numerous occasions to be completely fogged off and they reply to emails 4 days later each time you contact them.They confirmed it's with royal mail but they can't confirm a tracking number.This company are a complete shambles from top to bottom STAY CLEAR FROM THEM
# ==================================================
#
# ==================================================
# Title: Order no 445416 Wouldn’t send my missing items.
# Review: Purchased pack of 10 led strip connectors & tube of silicone. But only received silicone and 1 connector. Asked several times for the other connectors but kept saying sorry they made a mistake. Said i needed the other connectors to complete a job but instead of sending them out, just refunded the connector cost only. Meaning I would have to pay for post & packing again to re order. Not happy with the whole process.
# ==================================================
#
# ==================================================
# Title: Wating for 22 days to receive a cable
# Review: Wating for 22 days to receive a cable. In their website they said 4-7 days to be in stock and after 22 days after sending several emails they decided to ship. I asked them as they delayed the order to send with 1st delivery they ignored and send as normal delivery. Poor experience Following your response below I am not after a sorry as this means nothing. I had to contact you on many occasions rather you being pro active and advise me of the progress. If you have internal things to sort out it is not my issue. What I know despite 26 days since my order I have yet to receive my item. Sorry but this is unacceptable as you don't deliver what you advertise in your website and any promises are invalid.
# ==================================================
#
# ==================================================
# Title: Great service until you need to make a…
# Review: Great service until you need to make a return. Terrible refund procedures. Waiting nearly a month for a refund on an order which was sent straight back to them in same packaging it came in. Promised a refund several times over the past three weeks and still have not received it 😡 order no 443873
# ==================================================
#
# ==================================================
# Title: The worst seller i come across
# Review: The worst seller i have ever come across, you phone them you can't get hold of them, you  chat online but they are all automated, you can't  get an agent and when you email them you may or may not get a reply but when you do then that is a day after absolutely disgusting seller.I placed an order of 6 items, more than a month ago and received 3 items in two weeks time. Didn't even bother to say why? When i contacted them i couldn't get hold of them by calling, online chat then just sent an email why and where is the rest if the items? They said sorry a day after then when i said I don't need the rest of the order any more because its too late and also sent an email not to send any more items but they still sent 2 more items. I made a claim to paypal about it and sent 3 items back to the seller and ask to refund the money but what they want me to close paypal claim claim first then they will refund and i said No! If i cancel PayPal dispute what if you refuse to pay. Eventually i got the money back from paypal.
# ==================================================
#
# ==================================================
# Title: AVOID AVOID AVOID
# Review: AVOID AVOID AVOID, just read the other reviews, the website is misleading, the products are so over priced, the return service is ridiculous, they have no customer service and they keep lying about a refund. Not a single positive thing about this company... SIMPLY DO NOT USE. Thieves and cowboys, should be putout of business. They have replied but it is far from resolved. NI trading standards are now actively involved.
# ==================================================
#
# ==================================================
# Title: Avoid dealing with this company,i…
# Review: The order number is Order no. 441459Avoid dealing with this company,i received faulty goods tried reaching out can't get anyone,terrible customer service,waste of money,better companies out there to deal with.
# ==================================================
#
# ==================================================
# Title: Avoid purchasing from them
# Review: Avoid purchasing from them. I ordered cat food for nearly £50, but it still hadn’t arrived after three weeks. As a result, I canceled the order and received an email confirmation about the cancellation on July 11. However, I still haven’t received a refund despite contacting them multiple times via email. I’m now taking the matter to court because this is downright outrageous and disrespectful toward the customer.
# ==================================================
#
# ==================================================
# Title: Shocking customer service ..
# Review: Shocking customer service ... order 440940 product photo on the buying page doesn't match the product sent, cancellation request within 10 minutes of order ignored ... and you get to cover the cost of returning the wrong item to them!!! Ignorant support staff who send canned responses rather than answer your questions ... avoid at all costs.
# ==================================================
#
# ==================================================
# Title: Waiting for my order !!
# Review: Re order ID 434464.  Order placed 17th Sept. Chasing since 8th Oct. I hate leaving bad reviews but feel no other option here.  Still no sign of my order being delivered!!   Customer Service team have replied to my many emails which would 'seem' to indicate efficiency but they just repeat that "team is working to expedite shipping" or "shipment will be in 10-14 days" but still waiting.  Have asked how quickly I can get a refund if I cancel order but they never seem to address that question!  Avoid Avoid Avoid !!
# ==================================================
#
# ==================================================
# Title: Disgusting customer care
# Review: Order delayed. Impossible to speak to company representatives. Conflicting information given in emails; firstly saying item has been despatched and later email confirming item will be delayed. Tracking link in emails not working etc etc!!
# ==================================================
#
# ==================================================
# Title: Terrible customer service
# Review: Bought a 6 gang light switch,delivery was fine but product is faulty,I've been trying to get in touch through website can't get anyone,very poor customer service!Order no. 441459!!!! Update !!!Still no reply 2 weeks later, GET YOUR HOUSE IN ORDER ELECTRICAL WORLD.
# ==================================================
#
# ==================================================
# Title: Misled from the website picture
# Review: Misled from the website picture. It was not what was delivered. When I went through at least two hour of photos and chat calls then emails found out I was being charged for a return of the value close to item itself. Very disappointed with the experience won't shop with Electrical World ever again.
# ==================================================

# %% [markdown]
# All reviews are in english, otherwise we should select an NLP model suitable for mutilanguage.\
# With the next cleaning function we are going to remove:
#  - Remove: URLs, HTML code, emails, special characters
#  - Normalize: White spaces, new lines, unicode characters (é --> e)

# %%
df_clean = cleaning.clean_reviews_by_category(df, CAT)
df_clean.head()
# Out:
# 2026-04-19 11:03:37,598 [INFO] Filtering to category: 'Electronics & Technology' ...
# 2026-04-19 11:03:37,607 [INFO]   → 5,596 rows found across 69 companies.
# 2026-04-19 11:03:37,608 [INFO] Cleaning text columns: ['title', 'review', 'description'] ...
# 2026-04-19 11:03:37,671 [INFO]  ✓ 'title'
# 2026-04-19 11:03:37,968 [INFO]  ✓ 'review'
# 2026-04-19 11:03:38,479 [INFO]  ✓ 'description'
# 2026-04-19 11:03:38,481 [INFO] Cleaning complete.
#                    category               company  \
# 0  Electronics & Technology  www.richersounds.com
# 1  Electronics & Technology  www.richersounds.com
# 2  Electronics & Technology  www.richersounds.com
# 3  Electronics & Technology  www.richersounds.com
# 4  Electronics & Technology  www.richersounds.com
#
#                                          description  \
# 0  Richer Sounds is a British home entertainment ...
# 1  Richer Sounds is a British home entertainment ...
# 2  Richer Sounds is a British home entertainment ...
# 3  Richer Sounds is a British home entertainment ...
# 4  Richer Sounds is a British home entertainment ...
#
#                                             title  \
# 0                                         Dave 55
# 1             Great service from Richer Sounds...
# 2      Wanted a TV for an 84 year old relative...
# 3       IMFORMED FRIENDLY HELP FROM RICHER SOUNDS
# 4  Purchase of Hi-Fi Equipment From Richer Sounds
#
#                                               review  stars
# 0  Excellent service as always shout out to Jerom...      5
# 1  Great service from the Richer Sounds team at S...      5
# 2  Wanted a TV for an 84 year old relative whos s...      5
# 3  Excellent rapport and helpfulness with your So...      5
# 4  The Sales Assistant, Richard, was very helpful...      5

# %%
df['stars'].describe()
# Out:
# count    123181.000000
# mean          3.182658
# std           1.470769
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           5.000000
# max           5.000000
# Name: stars, dtype: float64

# %% [markdown]
# ## **1. EDA - Sector Overview**
#
# Once the set of reviews for the chosen sector has been cleaned, we can proceed with the exploratory data analysis

# %%
print(eda.dataset_overview.__doc__)
eda.dataset_overview(df_clean);
# Out:
#     Print a quick structural summary of the cleaned category DataFrame.
#
#     Shows shape, number of companies, star distribution, and basic
#     null/empty counts for the three key columns.
#
#     Parameters
#     ----------
#     df : pd.DataFrame
#         Cleaned DataFrame for a single category.
#
#     Returns
#     -------
#     pd.DataFrame
#         Summary table (also printed to stdout).
#
# =======================================================
#   DATASET OVERVIEW
# =======================================================
#   Total reviews      : 5,596
#   Unique companies   : 69
#   Star range         : 1 – 5
#   Avg stars (global) : 3.17
#
#         nulls  empty_strings
# column
# title       0              0
# review      0              0
# stars       0              0
# =======================================================

# %% [markdown]
# Next with the function `add_length_features` we add the following information at **Review Level**:
# - title_char_len   : number of characters in title
# - title_word_count : number of words in title
# - review_char_len  : number of characters in review
# - review_word_count: number of words in review
#
# With this extended dataframe: **df_feat** and the function `company_stats` we make a **Company level** dataframe, adding:
# - avg_stars        : mean star rating
# - pct_positive     : % reviews with stars >= 4
# - pct_neutral      : % reviews with stars == 3
# - pct_negative     : % reviews with stars <= 2
# - review_word_count: mean review word count (all reviews)
# - wc_positive      : mean word count of positive reviews (stars>=4)
# - wc_neutral       : mean word count of neutral reviews (stars==3)
# - wc_negative      : mean word count of negative reviews (stars<=2)
# - review_count     : total number of reviews

# %%
df_feat = eda.add_length_features(df_clean)
display(df_feat)
stats = eda.company_stats(df_feat)
display(stats)

print(f"\n  {len(stats)} companies found. Stats summary:")
print(stats.describe().round(2).to_string())
# Out:
#                       category               company  \
# 0     Electronics & Technology  www.richersounds.com
# 1     Electronics & Technology  www.richersounds.com
# 2     Electronics & Technology  www.richersounds.com
# 3     Electronics & Technology  www.richersounds.com
# 4     Electronics & Technology  www.richersounds.com
# ...                        ...                   ...
# 5591  Electronics & Technology          synthesia.io
# 5592  Electronics & Technology          synthesia.io
# 5593  Electronics & Technology          synthesia.io
# 5594  Electronics & Technology          synthesia.io
# 5595  Electronics & Technology          synthesia.io
#
#                                             description  \
# 0     Richer Sounds is a British home entertainment ...
# 1     Richer Sounds is a British home entertainment ...
# 2     Richer Sounds is a British home entertainment ...
# 3     Richer Sounds is a British home entertainment ...
# 4     Richer Sounds is a British home entertainment ...
# ...                                                 ...
# 5591  Synthesia is the world's 1 AI video communicat...
# 5592  Synthesia is the world's 1 AI video communicat...
# 5593  Synthesia is the world's 1 AI video communicat...
# 5594  Synthesia is the world's 1 AI video communicat...
# 5595  Synthesia is the world's 1 AI video communicat...
#
#                                                   title  \
# 0                                               Dave 55
# 1                   Great service from Richer Sounds...
# 2            Wanted a TV for an 84 year old relative...
# 3             IMFORMED FRIENDLY HELP FROM RICHER SOUNDS
# 4        Purchase of Hi-Fi Equipment From Richer Sounds
# ...                                                 ...
# 5591  Synthesia braucht Stunden um ein einfaches 1 m...
# 5592       False advertising and poor client experience
# 5593  Unusable Service and a Refund Policy Thats a R...
# 5594  Beware No-Refund Policy and Unusable App Features
# 5595         Spent nearly 2 1 2 hours setting up and...
#
#                                                  review  stars  \
# 0     Excellent service as always shout out to Jerom...      5
# 1     Great service from the Richer Sounds team at S...      5
# 2     Wanted a TV for an 84 year old relative whos s...      5
# 3     Excellent rapport and helpfulness with your So...      5
# 4     The Sales Assistant, Richard, was very helpful...      5
# ...                                                 ...    ...
# 5591  Du erstellst ein Video auf synthesia.io1,03 mi...      1
# 5592  The videos are good but the client experience ...      1
# 5593  My experience with Synthesia has been nothing ...      1
# 5594  Ive had a frustrating experience with Synthesi...      1
# 5595  Spent nearly 2 1 2 hours setting up and finish...      1
#
#       title_char_len  title_word_count  review_char_len  review_word_count
# 0                  7                 2              407                 69
# 1                 35                 5              343                 63
# 2                 42                 9              282                 54
# 3                 41                 6              308                 52
# 4                 46                 7              361                 65
# ...              ...               ...              ...                ...
# 5591              67                10             3561                580
# 5592              44                 6              351                 56
# 5593              92                14              775                123
# 5594              49                 7              838                131
# 5595              42                 9              771                142
#
# [5596 rows x 10 columns]
#                          avg_stars  pct_positive  pct_neutral  pct_negative  \
# company
# brokenfones.com               5.00        100.00         0.00          0.00
# licensel.com                  4.86        100.00         0.00          0.00
# pcrepairscheshire.co.uk       4.83        100.00         0.00          0.00
# wildviewcameras.co.uk         4.77        100.00         0.00          0.00
# techformusic.co.uk            4.67        100.00         0.00          0.00
# ...                            ...           ...          ...           ...
# www.richersounds.com          3.00         40.00        20.00         40.00
# www.yourspares.co.uk          3.00         40.40        19.19         40.40
# juicebitz.co.uk               2.99         39.39        20.20         40.40
# talktalkbusiness.co.uk        2.99         39.39        20.20         40.40
# www.hifix.co.uk               2.99         39.80        19.39         40.82
#
#                          avg_review_words  avg_title_words  review_word_count  \
# company
# brokenfones.com                     33.40             5.00              33.40
# licensel.com                        14.64             3.55              14.64
# pcrepairscheshire.co.uk             40.04             3.92              40.04
# wildviewcameras.co.uk               39.88             3.92              39.88
# techformusic.co.uk                  41.60             4.20              41.60
# ...                                   ...              ...                ...
# www.richersounds.com                78.02             6.08              78.02
# www.yourspares.co.uk                47.59             5.20              47.59
# juicebitz.co.uk                     66.17             5.67              66.17
# talktalkbusiness.co.uk              76.06             5.23              76.06
# www.hifix.co.uk                     63.84             5.38              63.84
#
#                          wc_positive  wc_neutral  wc_negative  review_count
# company
# brokenfones.com                33.40        0.00         0.00            20
# licensel.com                   14.64        0.00         0.00            22
# pcrepairscheshire.co.uk        40.04        0.00         0.00            24
# wildviewcameras.co.uk          39.88        0.00         0.00            26
# techformusic.co.uk             41.60        0.00         0.00            30
# ...                              ...         ...          ...           ...
# www.richersounds.com           67.88       80.65        86.85           100
# www.yourspares.co.uk           32.15       63.84        55.30            99
# juicebitz.co.uk                47.05       82.60        76.60            99
# talktalkbusiness.co.uk         47.85       75.70       103.75            99
# www.hifix.co.uk                44.33       58.47        85.40            98
#
# [69 rows x 11 columns]
#   69 companies found. Stats summary:
#        avg_stars  pct_positive  pct_neutral  pct_negative  avg_review_words  avg_title_words  review_word_count  wc_positive  wc_neutral  wc_negative  review_count
# count      69.00         69.00        69.00         69.00             69.00            69.00              69.00        69.00       69.00        69.00         69.00
# mean        3.38         53.65        16.12         30.23             58.74             5.17              58.74        46.90       62.70        67.24         81.10
# std         0.62         21.63         7.45         14.85             15.94             0.51              15.94         9.66       42.00        30.86         28.28
# min         2.99         39.39         0.00          0.00             14.64             3.55              14.64        14.64        0.00         0.00         20.00
# 25%         3.00         40.00        15.07         19.44             47.59             5.00              47.59        40.62       47.95        53.00         59.00
# 50%         3.00         40.00        20.00         40.00             60.83             5.22              60.83        47.05       60.90        74.15        100.00
# 75%         3.60         65.00        20.00         40.00             66.95             5.43              66.95        52.18       75.70        85.40        100.00
# max         5.00        100.00        25.00         40.82            104.74             6.27             104.74        70.05      303.00       142.23        100.00

# %% [markdown]
# ### **1.1 Star Rating Distribution (sector-wide)**

# %%
eda.plot_star_distribution(df_feat)
# Out:
# 2026-04-19 11:03:38,925 [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-04-19 11:03:38,928 [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %% [markdown]
# The rating distribution across the Electronics & Technology sector is
# slightly more dominant on positive reviews:
# - 5-star reviews leads at 24.6% (1374), followed by 4-star reviews at 21.7% (1216)
# - 3-star reviews are the second most common at 18.5% (1034) closely followed by 1-star
# (18.3%) and 2-star (16.9%).
#
# This pattern is characteristic not only of the electronics market,
# post-purchase issues (faulty products, delivery failures) generate
# strong negative reactions, beign 1-star reviews more common than 2-star reviews. While smooth transactions and good quality of the product generate strong
# praise making 4/5-star reviews more common than 3.

# %% [markdown]
# ### **1.2 Top & Bottom 10 Companies by Avg Stars**

# %%
stats
# Out:
#                          avg_stars  pct_positive  pct_neutral  pct_negative  \
# company
# brokenfones.com               5.00        100.00         0.00          0.00
# licensel.com                  4.86        100.00         0.00          0.00
# pcrepairscheshire.co.uk       4.83        100.00         0.00          0.00
# wildviewcameras.co.uk         4.77        100.00         0.00          0.00
# techformusic.co.uk            4.67        100.00         0.00          0.00
# ...                            ...           ...          ...           ...
# www.richersounds.com          3.00         40.00        20.00         40.00
# www.yourspares.co.uk          3.00         40.40        19.19         40.40
# juicebitz.co.uk               2.99         39.39        20.20         40.40
# talktalkbusiness.co.uk        2.99         39.39        20.20         40.40
# www.hifix.co.uk               2.99         39.80        19.39         40.82
#
#                          avg_review_words  avg_title_words  review_word_count  \
# company
# brokenfones.com                     33.40             5.00              33.40
# licensel.com                        14.64             3.55              14.64
# pcrepairscheshire.co.uk             40.04             3.92              40.04
# wildviewcameras.co.uk               39.88             3.92              39.88
# techformusic.co.uk                  41.60             4.20              41.60
# ...                                   ...              ...                ...
# www.richersounds.com                78.02             6.08              78.02
# www.yourspares.co.uk                47.59             5.20              47.59
# juicebitz.co.uk                     66.17             5.67              66.17
# talktalkbusiness.co.uk              76.06             5.23              76.06
# www.hifix.co.uk                     63.84             5.38              63.84
#
#                          wc_positive  wc_neutral  wc_negative  review_count
# company
# brokenfones.com                33.40        0.00         0.00            20
# licensel.com                   14.64        0.00         0.00            22
# pcrepairscheshire.co.uk        40.04        0.00         0.00            24
# wildviewcameras.co.uk          39.88        0.00         0.00            26
# techformusic.co.uk             41.60        0.00         0.00            30
# ...                              ...         ...          ...           ...
# www.richersounds.com           67.88       80.65        86.85           100
# www.yourspares.co.uk           32.15       63.84        55.30            99
# juicebitz.co.uk                47.05       82.60        76.60            99
# talktalkbusiness.co.uk         47.85       75.70       103.75            99
# www.hifix.co.uk                44.33       58.47        85.40            98
#
# [69 rows x 11 columns]

# %%
eda.plot_avg_stars_per_company(stats)

# %% [markdown]
# The top performers are dominated by **small specialist retailers**
# (brokenfones.com at 5.00, licensel.com at 4.86, pcrepairscheshire.co.uk
# at 4.83), all of which likely benefit from a niche focus and personalised
# service.
#
# The bottom 10 cluster tightly around **3.00 stars**, suggesting
# a floor effect — these companies are not catastrophically bad but are
# consistent, unable to differentiate themselves positively. Most of them
# are veteran companies that have more reviews than the top ones.
#
#
# Notably, the gap between the best (5.00) and worst (2.99) companies is
# almost 2 full stars, indicating **high performance dispersion** within
# the sector. This also suggest that really bad companies (1-2 star rate),
# tend to disappear due to high market competitivity.

# %% [markdown]
# ### **1.3 Review Word Count Distribution by Sentiment**

# %%
eda.plot_review_length_distribution(df_feat)

# %% [markdown]
# Negative reviewers write significantly **longer reviews** than positive
# ones. The box plot makes this stark: negative reviews (1–2★) have a
# median around 65 words and a wide IQR extending to ~100 words, while
# positive reviews (4–5★) cluster below 60 words with a much tighter
# spread. This is a well-known behavioural pattern, dissatisfied
# customers feel compelled to explain and justify their complaint in
# detail, while happy customers often leave short confirmatory reviews
# ("great service, fast delivery"). For NLP purposes, this means
# **negative reviews carry richer topic signal** and are worth analysing
# in more depth.

# %% [markdown]
# ### **1.4 Top 15 Companies by Avg Review Word Count**

# %%
eda.plot_avg_review_length_per_company(stats)

# %% [markdown]
# Companies with the longest reviews tend to cluster around **3.0–3.5
# average stars** (yellow- light green on the colour scale), confirming the
# sentiment–length relationship at company level, longer reviews on average tend to mean worst stars on average.
# phonebox.co.uk leads at ~105 words per review and sits in the 3.5 star range, suggesting
# its customers are engaged but divided. electricalworld.com does not appear in
# this top 15, suggesting its reviews are **shorter than sector average**,
# which will be confirmed in the positioning analysis.

# %% [markdown]
# ### **1.5 Company Summary Table (heatmap)**

# %%
display(eda.display_company_summary(stats))
# Out:
# <style type="text/css">
# #T_c4c3c_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_c4c3c_row0_col2, #T_c4c3c_row1_col2, #T_c4c3c_row2_col2, #T_c4c3c_row3_col2, #T_c4c3c_row4_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c4c3c_row0_col3, #T_c4c3c_row1_col3, #T_c4c3c_row2_col3, #T_c4c3c_row3_col3, #T_c4c3c_row4_col3, #T_c4c3c_row11_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_c4c3c_row1_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_c4c3c_row2_col1 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_c4c3c_row3_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_c4c3c_row4_col1 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_c4c3c_row5_col1 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_c4c3c_row5_col2 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_c4c3c_row5_col3 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_c4c3c_row6_col1 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_c4c3c_row6_col2 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_c4c3c_row6_col3 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_c4c3c_row7_col1 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_c4c3c_row7_col2 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_c4c3c_row7_col3, #T_c4c3c_row12_col3 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_c4c3c_row8_col1 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_c4c3c_row8_col2, #T_c4c3c_row10_col2 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_c4c3c_row8_col3 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_c4c3c_row9_col1 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_c4c3c_row9_col2 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_c4c3c_row9_col3 {
#   background-color: #fca486;
#   color: #000000;
# }
# #T_c4c3c_row10_col1 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_c4c3c_row10_col3 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_c4c3c_row11_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_c4c3c_row11_col2 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T_c4c3c_row12_col1 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_c4c3c_row12_col2 {
#   background-color: #278f48;
#   color: #f1f1f1;
# }
# #T_c4c3c_row13_col1 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_c4c3c_row13_col2 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_c4c3c_row13_col3 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_c4c3c_row14_col1 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_c4c3c_row14_col2 {
#   background-color: #60ba6c;
#   color: #f1f1f1;
# }
# #T_c4c3c_row14_col3 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_c4c3c_row15_col1 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_c4c3c_row15_col2 {
#   background-color: #7ac77b;
#   color: #000000;
# }
# #T_c4c3c_row15_col3 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_c4c3c_row16_col1 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_c4c3c_row16_col2 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_c4c3c_row16_col3 {
#   background-color: #e83429;
#   color: #f1f1f1;
# }
# #T_c4c3c_row17_col1 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_c4c3c_row17_col2 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_c4c3c_row17_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c4c3c_row18_col1 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_c4c3c_row18_col2 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_c4c3c_row18_col3 {
#   background-color: #79040f;
#   color: #f1f1f1;
# }
# #T_c4c3c_row19_col1 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_c4c3c_row19_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_c4c3c_row19_col3 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c4c3c">
#   <caption>Company Summary — Sorted by Avg Stars</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4c3c_level0_col0" class="col_heading level0 col0" >review_count</th>
#       <th id="T_c4c3c_level0_col1" class="col_heading level0 col1" >avg_stars</th>
#       <th id="T_c4c3c_level0_col2" class="col_heading level0 col2" >pct_positive</th>
#       <th id="T_c4c3c_level0_col3" class="col_heading level0 col3" >pct_negative</th>
#       <th id="T_c4c3c_level0_col4" class="col_heading level0 col4" >avg_review_words</th>
#       <th id="T_c4c3c_level0_col5" class="col_heading level0 col5" >avg_title_words</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >company</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4c3c_level0_row0" class="row_heading level0 row0" >brokenfones.com</th>
#       <td id="T_c4c3c_row0_col0" class="data row0 col0" >20</td>
#       <td id="T_c4c3c_row0_col1" class="data row0 col1" >5.00</td>
#       <td id="T_c4c3c_row0_col2" class="data row0 col2" >100.0%</td>
#       <td id="T_c4c3c_row0_col3" class="data row0 col3" >0.0%</td>
#       <td id="T_c4c3c_row0_col4" class="data row0 col4" >33</td>
#       <td id="T_c4c3c_row0_col5" class="data row0 col5" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c4c3c_level0_row1" class="row_heading level0 row1" >licensel.com</th>
#       <td id="T_c4c3c_row1_col0" class="data row1 col0" >22</td>
#       <td id="T_c4c3c_row1_col1" class="data row1 col1" >4.86</td>
#       <td id="T_c4c3c_row1_col2" class="data row1 col2" >100.0%</td>
#       <td id="T_c4c3c_row1_col3" class="data row1 col3" >0.0%</td>
#       <td id="T_c4c3c_row1_col4" class="data row1 col4" >15</td>
#       <td id="T_c4c3c_row1_col5" class="data row1 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c4c3c_level0_row2" class="row_heading level0 row2" >pcrepairscheshire.co.uk</th>
#       <td id="T_c4c3c_row2_col0" class="data row2 col0" >24</td>
#       <td id="T_c4c3c_row2_col1" class="data row2 col1" >4.83</td>
#       <td id="T_c4c3c_row2_col2" class="data row2 col2" >100.0%</td>
#       <td id="T_c4c3c_row2_col3" class="data row2 col3" >0.0%</td>
#       <td id="T_c4c3c_row2_col4" class="data row2 col4" >40</td>
#       <td id="T_c4c3c_row2_col5" class="data row2 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c4c3c_level0_row3" class="row_heading level0 row3" >wildviewcameras.co.uk</th>
#       <td id="T_c4c3c_row3_col0" class="data row3 col0" >26</td>
#       <td id="T_c4c3c_row3_col1" class="data row3 col1" >4.77</td>
#       <td id="T_c4c3c_row3_col2" class="data row3 col2" >100.0%</td>
#       <td id="T_c4c3c_row3_col3" class="data row3 col3" >0.0%</td>
#       <td id="T_c4c3c_row3_col4" class="data row3 col4" >40</td>
#       <td id="T_c4c3c_row3_col5" class="data row3 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c4c3c_level0_row4" class="row_heading level0 row4" >techformusic.co.uk</th>
#       <td id="T_c4c3c_row4_col0" class="data row4 col0" >30</td>
#       <td id="T_c4c3c_row4_col1" class="data row4 col1" >4.67</td>
#       <td id="T_c4c3c_row4_col2" class="data row4 col2" >100.0%</td>
#       <td id="T_c4c3c_row4_col3" class="data row4 col3" >0.0%</td>
#       <td id="T_c4c3c_row4_col4" class="data row4 col4" >42</td>
#       <td id="T_c4c3c_row4_col5" class="data row4 col5" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c4c3c_level0_row5" class="row_heading level0 row5" >shop.blackcatpc.co.uk</th>
#       <td id="T_c4c3c_row5_col0" class="data row5 col0" >28</td>
#       <td id="T_c4c3c_row5_col1" class="data row5 col1" >4.61</td>
#       <td id="T_c4c3c_row5_col2" class="data row5 col2" >92.9%</td>
#       <td id="T_c4c3c_row5_col3" class="data row5 col3" >3.6%</td>
#       <td id="T_c4c3c_row5_col4" class="data row5 col4" >45</td>
#       <td id="T_c4c3c_row5_col5" class="data row5 col5" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c4c3c_level0_row6" class="row_heading level0 row6" >ahappliancerepairs.co.uk</th>
#       <td id="T_c4c3c_row6_col0" class="data row6 col0" >29</td>
#       <td id="T_c4c3c_row6_col1" class="data row6 c

# %% [markdown]
# The heatmap reveals a clean **bifurcation** in the sector: companies
# in the top half (brokenfones, licensel, pcrepairscheshire) achieve
# near-100% positive rates with 0% negative, while the bottom half
# (phonebox, computerangels, scgconnected) see positive rates drop to
# 55–65% with negative rates climbing to 19–26%. The avg_review_words
# column reinforces the earlier finding: phonebox.co.uk's 105-word
# average is the highest in the table and coincides with its 26% negative
# rate — its customers have a lot to complain about. electricalworld.com
# is not visible in this top-20 slice, which foreshadows its low
# percentile positioning.
# Also this table confirms that top positioned companies are more recent companies
# due to the lower review count.

# %% [markdown]
# ## **2. EDA - Competitive Positioning — electricalworld.com**
#
# Now let's study where's our target company positioned

# %%
stats = stats.reset_index()
print(f"\n{'='*55}")
print(f"  COMPETITIVE POSITIONING — {TARGET}")
print(f"  Category : {CAT}")
print(f"  Companies: {stats['company'].nunique()}")
print(f"{'='*55}\n")

df_clean.loc[df_clean['company']==TARGET, 'description'].unique()
# Out:
# =======================================================
#   COMPETITIVE POSITIONING — electricalworld.com
#   Category : Electronics & Technology
#   Companies: 69
# =======================================================
# <ArrowStringArray>
# ['Now with over 16,000 Reviews on Reviews.io, Electrical World was founded from humble beginnings by Managing Director John Coalter an experienced electrician who began his career as a businessman at the age of 20, when he launched his first electrical contract company. We now offer worldwide delivery and have a vast range of DIY and B2B products available at extremely competitive prices!']
# Length: 1, dtype: str

# %% [markdown]
# ### **2.1 Avg Star Rating Distribution (KDE)**

# %%
eda.plot_stars_positioning(stats, CAT, TARGET)
# Out:
#   ► electricalworld.com avg stars: 3.00  |  Sector median: 3.00  |  Percentile: 4th

# %% [markdown]
# ``electricalworld.com`` sits at the **4th percentile** with an average of slighlty more than
# 3.00 stars — at the very bottom of the sector distribution. Most competitors cluster between 3-3.25, meaning our
# company is located at, more or less the median. The distribution is right-skewed with a long tail of high performers,
# pulling the average above electricalworld.com. Although most companies are close in ratings, in practical terms,
# **96% of competitors in this sector have a higher average rating**.
# This is a signal that there is a lot of room for improvement.

# %% [markdown]
# ### **2.2 Sentiment Split vs Benchmarks**

# %%
eda.plot_sentiment_pct_comparison(stats, TARGET)

# %% [markdown]
# The stacked bar chart tells a direct story. electricalworld.com has
# **40% positive and 40% negative reviews** — a perfectly split, deeply
# polarised customer base. This compares unfavourably to:
# - The **sector median**: exactly the same as electricalworld
# - The **best company**: 100% positive, 0% negative
# - Even the **worst company** (★2.99): 40% positive, 41% negative —
#   essentially identical to electricalworld.com
#
# The fact that electricalworld.com matches the *worst-performing
# company* in the sector on both positive and negative rates is the
# clearest possible summary of its competitive position. The 20% neutral
# block is average, offering no differentiation. **There is no meaningful
# positive base to build on without first addressing the negative reviews.**

# %% [markdown]
# ### **2.3 Percentile Dashboard (3 KPIs)**

# %%
eda.plot_percentile_dashboard(stats, CAT, TARGET)

# %% [markdown]
# Three KPIs consolidate the positioning picture:
#
# | KPI | Value | Percentile |
# |-----|-------|------------|
# | % Positive reviews | 40% | **P4** |
# | % Negative reviews | 40% | **P41** |
# | Avg star rating | 3.00 | **P4** |
#
# The P41 on negative reviews is actually the *least* alarming figure —
# being at the 41st percentile for negative rate means the company is
# slightly below the median on that metric, which sounds counterintuitive
# given the 40% negative rate. This reflects that many competitors also
# have significant negative volumes. The real problem is the **P4 on
# positive reviews**: only 4% of competitors have fewer positive reviews,
# meaning electricalworld.com is almost uniquely bad at generating
# satisfied customers.

# %% [markdown]
# ### **2.4 Word Count by Sentiment vs Sector**

# %%
eda.plot_word_count_by_sentiment(stats, TARGET)

# %% [markdown]
# electricalworld.com's reviewers show a striking pattern:
#
# | Sentiment | Our avg words | Sector IQR | Percentile |
# |-----------|--------------|------------|------------|
# | Negative | 79w | ~55–85w | **P60** |
# | Neutral | 82w | ~50–75w | **P82** |
# | Positive | 39w | ~41–55w | **P18** |
#
# Negative and neutral reviewers write **more than sector average**
# (P60 and P82 respectively), confirming that dissatisfied customers
# are verbose and detailed in their complaints. Positive reviewers
# write much less than competitors' happy customers (P18, only 39 words)
# — suggesting that the small share of satisfied customers leave
# **thin, unconvincing praise** that carries little weight. This imbalance
# matters for reputation: long negative reviews are more persuasive to
# prospective buyers than short positive ones.

# %%
df_clean.to_csv('../datasets/df_clean')

# %% [markdown]
# Finally we save the cleaned dataframe to import it later in the NLP Notebook
